# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# 👋 **Hello! I'm Dot, your AI reviewer.**
#
# I've completed the first pass of your code review. Below, you'll find my comments and suggestions for improvement.
#
# **What should you do next?**
#
# 1. **Review:** check my comments in the notebook below.
# 2. **Decide:**
# * **Agree with the feedback?** Great! Update your code accordingly.
# * **Disagree or think it's a mistake?** No problem! You can keep your code exactly as it is.
#
#
# 3. **Resubmit:** Send your project back. **Your next iteration will be reviewed by a human expert**, whether you made changes or not.
#
# -------------------------------------------------------------------------------------------------------------
# Please find my comments below—**I kindly ask that you do not move, modify, or delete them**.
#
# You can find my comments highlighted in green, yellow, or red boxes like this:
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Success. Everything is done succesfully.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Remarks. Some recommendations.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration X</b> <a class="tocSkip"></a>
#
# Needs fixing. The block requires some corrections.
# </div>

# %% [markdown]
# <div style="border: 5px solid red; padding: 10px; margin: 0px">
# <b>Reviewer's comment V2 </b>
#
# **Hello Ryan,**
#
# My name is **John Dickson** (https://hub.tripleten.com/u/13efa053) and today I'll be reviewing your project!
#
# overall the core of the project has been done, however in several places there are layers of unneeded complexity that makes the code more difficult to read than is needed.
#
# In addition it is important to follow proper conventions (such as variable naming conventions) to make the code easier to read and work with. The project is an introduction to some core python and pandas fundamentals.
# </div>

# %% [markdown]
# <div style="border:solid red 2px; padding: 20px">
# <b>Reviewer’s comment v3</b>
#
# <b>Overall Feedback</b>
#
# Hello Ryan!
#
# My name is <b>Carlos Huapaya</b> and I will be your reviewer in this iteration.
#
# You can find me on the HUB as https://hub.tripleten.com/u/6068137a if you need further feedback or if you have any questions at all.
#
# Thank you for submitting your updated project. I can see a lot of progress compared to earlier iterations — Tasks 1 through 7 are now in good shape, and your workflow shows a solid understanding of pandas: cleaning column names, correcting values, filtering correctly, and building reusable functions.
#
# ---
#
# You’ll find specific feedback in the notebook in the **Reviewer's comment v3:** sections.
#
# <b>✅ What was good</b>
# <ul>
#   <li>You handled the column-cleaning task well and kept your dataset consistent for later steps.</li>
#   <li>Your filtering logic for the required actor/title tasks is correct and readable.</li>
#   <li>The functions you created in Tasks 5–7 work and show good structure.</li>
# </ul>
#
# <b>❗ What needs to be fixed to approve</b>
# <ul>
#     <li><b>Task 8 is still not aligned with the requirements.</b> The function must return a single category string only: <code>"Excellent"</code>, <code>"Good"</code>, <code>"Average"</code>, or <code>"Low"</code>. If the title isn’t found, it must return exactly <code>"Title not found"</code>. The current solution is over-engineered for this task (handling duplicates/remakes and building long-formatted messages). While it’s creative, it increases complexity and moves away from what the task is testing. Please simplify it to match the required output.</li>
#     <li><b>In some parts, the code could be simplified.</b> This is especially important in production environments, where clarity and maintainability matter a lot. Simpler code is easier to read, easier to debug, and in many cases even more efficient (cpu / memory). Keep in mind that clarity often outweighs complexity — sometimes, simpler is better.</li>
# </ul>
#
# Once Task 8 returns the expected outputs exactly, your project will be ready for approval.
#
# ---
#
# <p style="margin-top: 12px"><b>How to read my comments</b></p>
#
#   <div class="alert alert-success"><b>✅ Success:</b> correct and well done</div>
#   <div class="alert alert-warning"><b>💡 Recommendation:</b> works, but could be clearer / stronger / more efficient</div>
#   <div class="alert alert-danger"><b>❗ Needs Fix:</b> affects correctness — must be fixed for approval</div>
#
#   <p style="margin-top: 10px">
#   <b>Please don’t move, edit, or delete my comments.</b>
#   If you have any comments or questions, I'd be happy to read them within these boxes:
#   </p>
#
#   <div style="background:#90d5ec; padding: 10px 12px; border-radius: 8px; margin-top: 10px">
#     <b>🗣 Student notes:</b> Student's comments with thoughts, questions, or justification.
#   </div>
# </div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Reviewer's comment v4:</b>
#
#
# <b>Overall Feedback</b>
#
# Hello Ryan,
#
# My name is **Gerardo Flores** and you can find me on the HUB as https://hub.tripleten.com/u/1949959f
#
# You’ve submitted another project—great work! Your commitment to pushing through the challenges of this program is admirable.
#
# After reviewing your submission, it is approved.
#
#
# You can find my more detailed notes within your project notebook in the `Reviewer's comment v4:` section.
#
#
# If you find yourself uncertain or in need of further insights, never hesitate to consult with your tutor or ask your questions here. We are here to guide and assist you.

# %% [markdown]
# # Project: Data Analysis with Pandas
#
# In this project, you will work with a dataset containing information about movies and shows. You will use the pandas library to read, clean, and analyze the data. This project will help you practice working with DataFrames, indexing, and data manipulation using pandas.
#
#
# ## Dataset Description
#
# The dataset `movies_and_shows.csv` contains information about various movies and shows, including:
#
# - **name**: The name of the actor or actress.
# - **Character**: The character they played.
# - **r0le**: The role type (e.g., ACTOR).
# - **TITLE**: The title of the movie or show.
# - **Type**: Whether it's a MOVIE or SHOW.
# - **release Year**: The year it was released.
# - **genres**: A list of genres the movie or show belongs to.
# - **imdb sc0re**: The IMDb score of the movie or show.
# - **imdb v0tes**: The number of votes on IMDb.
#
# Here's a small sample of the dataset:
#
# | name              | Character                         | r0le   | TITLE        |  Type | release Year | genres             | imdb sc0re | imdb v0tes |
# |-------------------|-----------------------------------|--------|--------------|-------|--------------|--------------------|------------|------------|
# | Robert De Niro    | Travis Bickle                     | ACTOR  | Taxi Driver  | MOVIE | 1976         | ['drama', 'crime'] | 8.2        | 808582     |
# | Jodie Foster      | Iris Steensma                     | ACTOR  | Taxi Driver  | MOVIE | 1976         | ['drama', 'crime'] | 8.2        | 808582     |
# | Albert Brooks     | Tom                               | ACTOR  | Taxi Driver  | MOVIE | 1976         | ['drama', 'crime'] | 8.2        | 808582     |
# | Harvey Keitel     | Matthew 'Sport' Higgins           | ACTOR  | Taxi Driver  | MOVIE | 1976         | ['drama', 'crime'] | 8.2        | 808582     |
# | Cybill Shepherd   | Betsy                             | ACTOR  | Taxi Driver  | MOVIE | 1976         | ['drama', 'crime'] | 8.2        | 808582     |

# %% [markdown]
# ## Getting Started
#
# Let's begin by setting up our environment.
#
# ### Importing Libraries
#
# First, we need to import the necessary libraries.
#
# **Instructions:**
#
# - Import the `pandas` library, which we will use for data manipulation.

# %%
#Import the pandas library as 'pd'
import pandas as pd

# %% [markdown]
# We will load the dataset into a pandas DataFrame to begin our analysis.
#
# **Instructions:**
#
# - Read the `movies_and_shows.csv` file into a DataFrame. It is in the /datasets directory so the full path to include in the read_csv method will be "/datasets/movies_and_shows.csv"
# - Display the first few rows of the DataFrame to get an initial look at the data.
#
# **Hints:**
#
# - Use `pd.read_csv()` to read the CSV file and store it in a variable called "df".
# - Use the `.head()` method to display the first few rows.

# %%
# Read the dataset into a DataFrame
df = pd.read_csv('/datasets/movies_and_shows.csv') #Changed ds to df

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# The instructions indicate loading the CSV into a variable named `df`, but you used `ds`. That naming mismatch can cause later cells (or grading checks) to fail even if the file loads correctly.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v3:</b> <a class="tocSkip"></a>
#
# Well done!
#
# </div>

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#               name                Character   r0le        TITLE   Type  \
# 0   Robert De Niro            Travis Bickle  ACTOR  Taxi Driver  MOVIE
# 1     Jodie Foster            Iris Steensma  ACTOR  Taxi Driver  MOVIE
# 2    Albert Brooks                      Tom  ACTOR  Taxi Driver  MOVIE
# 3    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR  Taxi Driver  MOVIE
# 4  Cybill Shepherd                    Betsy  ACTOR  Taxi Driver  MOVIE
#
#    release Year              genres  imdb sc0re  imdb v0tes
# 0          1976  ['drama', 'crime']         8.2    808582.0
# 1          1976  ['drama', 'crime']         8.2    808582.0
# 2          1976  ['drama', 'crime']         8.2    808582.0
# 3          1976  ['drama', 'crime']         8.2    808582.0
# 4          1976  ['drama', 'crime']         8.2    808582.0

# %% [markdown]
# Understanding the structure and content of your data is crucial before performing any analysis.
#
# **Instructions:**
#
# - Use the `.info()` method to get information about the DataFrame.
# - Identify any issues with the Column names.

# %%
# Get information about the DataFrame and print the column names
df.info()
"""
name = capitalization, spacing error
r0le = typo
TITLE = capitalizaton
Type = spacing error
release Year = capitalization
genres = capitalization
imdb sc0re = capitalization, typo
imdb v0tes = capitalization, typo
Datatypes are all correct
"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85579 entries, 0 to 85578
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0      name       85579 non-null  object
#  1   Character     85579 non-null  object
#  2   r0le          85579 non-null  object
#  3   TITLE         85578 non-null  object
#  4     Type        85579 non-null  object
#  5   release Year  85579 non-null  int64
#  6   genres        85579 non-null  object
#  7   imdb sc0re    80970 non-null  float64
#  8   imdb v0tes    80853 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 5.9+ MB
# '\nname = capitalization, spacing error\nr0le = typo\nTITLE = capitalizaton\nType = spacing error\nrelease Year = capitalization\ngenres = capitalization\nimdb sc0re = capitalization, typo\nimdb v0tes = capitalization, typo\nDatatypes are all correct\n'

# %% [markdown]
# ## Task 1: Data Cleaning
#
# Let's clean the data to fix issues with the column names
#
# **Instructions:**
# - Rename the columns to correct any errors and make them consistent.
#
# **Hints:**
#
# - Use the `.rename()` method to rename columns.
# - Pass a dictionary to the `columns` parameter of `.rename()`, where the keys are the old column names and the values are the new names.
# - Remove unnecessary whitespace from the column names.

# %%
# Rename columns to make them consistent and correct errors
df.columns = df.columns.str.strip() #Implemented a whitespace stripping method for the column string objects, instead of manually typing out spaces in the dict
df = df.rename(
    columns={
        'name':'name', #left this line alone for consistency and ensuring everything is handled the same
        'r0le':'role',
        'TITLE':'title',
        'Type':'type',
        'release Year':'release_year',
        'genres':'genres',
        'imdb sc0re':'imdb_score',
        'imdb v0tes':'imdb_votes',
    }
)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Your rename dictionary doesn’t match the dataset’s actual column names (for example, the file has `name` and `Type`, not `'   name'` and `'  Type'`), so the renaming may not reliably apply. Consider first stripping whitespace from all column names, then renaming the real column names. Also, be mindful that many course templates expect standardized *lowercase* names (e.g., `name`, `title`, `release_year`, `imdb_score`); switching to capitalized names is fine only if you stay consistent everywhere and it won’t break later required steps.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment V2</b>
#
# The column names do not meet the required naming convention. The names should have no upper case characters and `_` should be used in place of spaces.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v3:</b> <a class="tocSkip"></a>
#
# Well done!
#
# </div>

# %%
# Print the updated column names to confirm changes
print(df.columns)
# Out:
# Index(['name', 'Character', 'role', 'title', 'type', 'release_year', 'genres',
#        'imdb_score', 'imdb_votes'],
#       dtype='object')

# %% [markdown]
# ## Task 2: Correcting a Misspelled Name in the Data
#
# While analyzing the dataset, you notice that some names are misspelled or contain special characters due to encoding issues. Accurate data is essential for reporting and recommendations, so let’s correct one of these entries.
#
# ### Instructions
#
# 1. **Locate the Row with the Incorrect Name**:
#    - Use `.loc[]` to retrieve the row where `name` is `"In??s Prieto"`.
#    - You can locate a row based on the index (85576) and column name called "name".
#    - Print the row to verify that you have the correct one.
#
#
# 2. **Correct the Name**:
#    - Using `.loc[]`, update the `name` column for this row to "Ines Prieto."
#
# 3. **Verify the Correction**:
#    - Print the row again to ensure that the name has been corrected.

# %%
# Locate the row with the incorrect name
print(df.loc[85576, 'name'])
print(df.loc[85576, 'title']) #Confirmar la actriz correcta, que es Latina
# Out:
# In??s Prieto
# Lokillo

# %%
# Correct the name
df.loc[85576, 'name'] = 'Ines Prieto' #Dot hated me using the correct é even though the DataFrame accepts this character. Changed back to e

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# The task asks to correct the value to exactly "Ines Prieto" (without an accent). Using "Inés Prieto" means later filters for "Ines Prieto" won’t match this row.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment V2</b>
#
# We should not be resetting the name to the incorrect one here.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v3:</b> <a class="tocSkip"></a>
#
# Well done! It's good that you wanted to write the name with the accent. However, we should follow the task instructions, which mention the name without the accent.
#
# </div>

# %%
# Verify the correction
df.loc[85576, 'name']
# Out:
# 'Ines Prieto'

# %% [markdown]
# ## Task 3: Finding All Movies and Shows Featuring Ines Prieto
#
# Now that we've corrected the spelling of "Ines Prieto" in the dataset, let's find all the TV shows and movies she has acted in. This type of filtering is helpful for generating actor-specific profiles or building a list of their works.
#
# ### Instructions
#
# 1. **Filter by Actor’s Name**:
#    - Use a filtering condition to select rows where the `name` column is equal to `"Ines Prieto"`.
#
# 2. **Display Relevant Columns**:
#    - From each matching row, retrieve only the `title`, `release_year`, `imdb_score`, and `genres` columns for a clear, concise output.
#
# **Hint:**
#
# To filter rows based on a specific value in a column, use a condition inside df[ ... ]. In this case, check if the name column equals "Ines Prieto". Then, select only the columns you need (like title, release_year, imdb_score, and genres) by specifying them in double brackets [ [ ... ] ].

# %%
# Filter rows where the actor's name is "Ines Prieto" and display the title, release_year, genres, and imdb_score
names_list = df.loc[0:, 'name']

ip_list = df[names_list == 'Ines Prieto']  

ip_list_cut = ip_list[['title', 'release_year', 'genres', 'imdb_score']]

#Removed IP_list3 which checked for the ultimately correct spelling of Inés Prieto
#Search for alternate copies of In??s in the .csv dataset was removed
#Fixed PEP8 variable conventions

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# The task is looking for one clear filter where the name equals exactly "Ines Prieto", and then displaying only the requested columns (`title`, `release_year`, `imdb_score`, `genres`). Right now you’re checking multiple name variants and keeping extra columns, which makes the result drift from the instructions.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment V2</b>
#
# Indeed there was more than one incorrect version, but we only care about the one. We only need to display the one assigned for our task.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v3:</b> <a class="tocSkip"></a>
#
# Well done!
#
# </div>

# %%
# Display the result
print(f"The movies and shows featuring Ines Prieto in our dataset consist of the following:\n\n{ip_list_cut}")
# Out:
# The movies and shows featuring Ines Prieto in our dataset consist of the following:
#
#          title  release_year      genres  imdb_score
# 85576  Lokillo          2021  ['comedy']         3.8

# %% [markdown]
# ## Task 4: Finding Highly Rated Movies
#
# We want to identify movies with an IMDb rating of at least **9.0**. This list could be helpful for curating a "Top Movies" section based on high ratings.
#
# ### Instructions
#
# 1. **Filter for High IMDb Scores**:
#    - First, filter the DataFrame to include only rows where the `imdb_score` is greater than 9.0.
#
# 2. **Extract the Titles**:
#    - From this filtered DataFrame, select only the `title` column, which contains the names of the movies.
#
# 3. **Get Unique Titles**:
#    - Convert the resulting list of titles to a set to remove any duplicate titles. Using `set()` will keep only unique movie names.
#
#    - *Example*: `unique_titles = set(high_score_titles)`
#
# 4. **Print the Unique Titles**:
#    - Display the final set of unique movie titles to see the list of top-rated movies.

# %%
# Filter for movies with an IMDb score above 9.0
high_score_list = df[df['imdb_score'] > 9.0]

# Extract the 'title' column from the filtered DataFrame
high_score_titles = high_score_list['title']

# Get a unique set of titles
high_score_titles_stripped = set(high_score_titles) #Changed to set() per Dot instructions. Overlooked set() function being in the instructions

# Print the unique titles
print(f"These are the highest rated films in the dataset: \n{high_score_titles_stripped}")

#Fixed variable names to PEP8 conventions
#Fixed the logical indexing method to simplify it
# Out:
# These are the highest rated films in the dataset:
# {'Avatar: The Last Airbender', 'Breaking Bad', 'The Last Dance', 'Kota Factory', 'Reply 1988', 'Major', 'My Mister', 'Our Planet'}

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Recurring requirement: when the instructions ask for “unique titles as a Python `set`”, `drop_duplicates()` isn’t a substitute—it keeps a pandas object. Convert the titles to a Python set to meet the task exactly.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment V2</b>
#
# There is no logical reason to create a scores list like this when we can use the logical indexing directly as taught [here](https://tripleten.com/trainer/aiml/lesson/6530f724-dd31-4858-a9b9-17c29b5051cf/?from=program): https://tripleten.com/trainer/aiml/lesson/6530f724-dd31-4858-a9b9-17c29b5051cf/?from=program
#
# In addition there is no need to flatten the dataframe into an array for `set` to work, `set` will work directly with a series.
#
# I notice that you are not following variable naming conventions that you have been taught, and that are set out by python style guides such as PEP 8 https://peps.python.org/pep-0008/#function-and-variable-names
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v3:</b> <a class="tocSkip"></a>
#
# Well done!
#
# </div>

# %% [markdown]
# ## Task 5: Creating a Function to Find Unique Top-Rated Movies
#
# In this task, we’ll create a function to find unique movies with an IMDb score above a certain threshold that the user provides.
#
# ### Instructions
#
# 1. **Define the Function**:
#    - Start by creating a function called `get_unique_top_movies` that takes one parameter, `min_score`.
#
# 2. **Filter the Data**:
#    - Inside the function, create a new variable (e.g., `high_score_df`) that stores rows where the `imdb_score` is greater than or equal to `min_score`.
#
# 3. **Extract Movie Titles**:
#    - In a new variable (e.g., `high_score_titles`), select the `title` column from the filtered DataFrame.
#
# 4. **Remove Duplicate Titles**:
#    - Convert `high_score_titles` to a set using `set(high_score_titles)` to automatically remove duplicates, ensuring each title appears only once.
#
# 5. **Return the Unique Titles**:
#    - Make sure the function returns the `unique_titles` set.

# %%
# Define the function
def get_unique_top_movies(min_score):
    
    # Filter for movies with IMDb score above min_score     #This instruction was initially unclear. Prompted me to use > instead of >= operator, which confused me
    high_score_df = df[df['imdb_score'] >= min_score]
    
    # Extract the 'title' column
    high_score_titles = high_score_df['title'].values
    
    # Remove duplicate titles
    high_score_titles_unique = set(high_score_titles)
    
    # Return unique titles
    return high_score_titles_unique

#All above board here
#Simplified logic of first line of the function in reponse to v3 comments and removed the additional intermediary variable

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# The function is expected to return a `set` of unique titles, but it currently returns a DataFrame. Also, your score filtering is inconsistent (`>= min_score` and then overwritten with `> min_score`), which makes the first filter redundant and excludes titles exactly equal to `min_score`.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment v3:</b> <a class="tocSkip"></a>
#
# Well done! However, `imdb_score = df.loc[0:, 'imdb_score']` can be much simpler: `df['imdb_score']`, and it doesn't have to be assigned to a variable (`imdb_score`). You could filter like this:
#
# `high_score_df = df[df['imdb_score'] >= min_score]`
#
# </div>

# %%
# Test the function
print(get_unique_top_movies(9.0))
# Out:
# {'Avatar: The Last Airbender', 'Attack on Titan', 'Arcane', 'Breaking Bad', 'The Last Dance', 'Leah Remini: Scientology and the Aftermath', 'Kota Factory', 'Reply 1988', 'Okupas', 'Major', 'My Mister', 'DEATH NOTE', 'Hunter x Hunter', 'Our Planet'}

# %% [markdown]
# ## Task 6: Creating a Function to Find Top Movies from a Specific Decade
#
# Let’s create a function to retrieve movies from a particular decade with high IMDb ratings. This function can be useful for generating lists of top-rated movies from different time periods.
#
# ### Instructions
#
# 1. **Define the Function**:
#    - Create a function called `get_top_movies_from_decade` that accepts `decade_start` and `min_score` as parameters.
#
# 2. **Filter by Decade**:
#    - Inside the function, filter the DataFrame to include only movies where `release_year` is within the specified decade.
#    - *Hint*: You can achieve this by checking that `release_year` is between `decade_start` and `decade_start + 9`
#
# 3. **Filter by IMDb Score**:
#    - Further filter this subset to include only movies where `imdb_score` is greater than or equal to `min_score`.
#
# 4. **Extract Movie Titles**:
#    - From the resulting DataFrame, select the `title` column and remove duplicates using set().
#
# 5. **Return the List of Titles**:
#    - Return the set of the best movies from that decade.
#
# By completing this task, you’ll have a function that returns unique, top-rated movies from a specified decade. This is useful for highlighting standout movies from different eras, perfect for “Best of the Decade” features!

# %%
# Define the function
def get_top_movies_from_decade(decade_start, min_score):
    # Filter for movies released within the decade
    movies_not_shows = df[df['type'] == 'MOVIE'] #Planted this to strip Movies only. Won't catch miscoded types (i.e. 'the movie') evident from Task 3
                                                 #Double-checked with != operator: returned only TV shows. There are no miscoded movies missed by my Boolean
   
    release_year = movies_not_shows['release_year']
    from_decade =  movies_not_shows[(decade_start <= release_year) & (release_year <= (decade_start+9))] #Using a pandas Boolean operator
    
    # Further filter by IMDb score
    high_score_decade_df = from_decade[from_decade['imdb_score'] >= min_score] 
    high_score_decade_titles = high_score_decade_df['title']

    # Extract and remove duplicate titles
    best_of_decade = set(high_score_decade_titles) #Dot Revision: Changed from .drop_duplicates() to set(). Seems cool to know both.

    # Return unique titles
    return best_of_decade

#All logic streamlined and fixed

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# Reminder (same as earlier): this function is required to return a Python `set` of unique titles, but it currently returns a DataFrame after `drop_duplicates()`.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment V2</b>
#
# I am unsure why you are using `.loc` as in `df[(df.loc[0:,'Type'] == 'MOVIE')]`, this is creating far more complexity than needed and is reducing readability. We can reference the column without the `.loc` and it will include all rows automatically.
# </div>

# %%
# Test the function
print(get_top_movies_from_decade(1990, 8.5))
print(f"\nThis business with the é character looks like it's a running theme in the initial dataset.")
# Out:
# {'Forrest Gump', 'Se7en', 'GoodFellas', 'L??on: The Professional', 'Bill Hicks: Revelations'}
#
# This business with the é character looks like it's a running theme in the initial dataset.

# %% [markdown]
# ## Task 7: Creating a Function to List All Actors in a Given Title
#
# Imagine you want to list all the actors in a specific movie or show. Let’s create a function that takes a `title` as input and returns the names of all actors in that title, combined into a single string.
#
#
# ### Instructions
#
# 1. **Define the Function**:
#    - Create a function called `get_actors_for_title` that accepts one parameter, `title`.
#
# 2. **Filter by Title and Role**:
#    - Inside the function, filter the DataFrame to select rows where the `title` column matches the provided `title` parameter and the `role` column is `"ACTOR"` (to ensure you only retrieve actors).
#
# 3. **Extract Actor Names**:
#    - From this filtered DataFrame, select only the `name` column to get the actor names.
#
# 4. **Combine Names into a Single String**:
#    - Use `', '.join()` to combine the list of actor names into a single string, with each name separated by a comma.
#
# 5. **Return the Result**:
#    - Return the resulting string of actor names.
#
#
# This function will allow you to retrieve and format a list of actors for any movie or show title, which is useful for creating cast lists or displaying actors for specific titles.

# %%
# Define the function
def get_actors_for_title(title):
    # Filter for rows with the specified title and role as 'ACTOR'
    actors_df = df[(df['title'] == title) & (df['role'] == "ACTOR")] #The != operator here reveals that DIRECTOR exists as a Role

    # Extract the 'name' column for actor names
    actors_names = actors_df['name']

    # Combine names into a single string
    result = ', '.join(actors_names) #Dot Revision: .to_string() changed to .join() method for correct code output.
    
    # Return the result
    return result #The type function tells me this is indeed a whole string.

#All above board here. Streamlined the logical indexing and fixed DataFrame header call capitalization
#Remove extraneous comments from past revisions to improve readability
#Simplified logic and variable names in reponse to v3 comments. Removed the additional intermediary variable

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# The task asks for a comma-separated string using `', '.join(...)`. Using `to_string()` produces a formatted, newline-style output instead. Consider converting the names Series to a Python list and joining them with commas before returning.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment v3:</b> <a class="tocSkip"></a>
#
# Great! However, this block:
#
# ```
# selected_work = df[(df['title'] == title)]
#
# selected_work_actorfilter = selected_work[selected_work['role'] == 'ACTOR']
# ```
#
# can be much simpler:
#
# `actors_df = df[(df['title'] == title) & (df['role'] == "ACTOR")]`
#
# and variable names can also be much simpler, like:
#
# `selected_work_actorfilter` -> `actors_df`
#
# `selected_work_actorfilter_actornames` -> `actors_names`
#
# </div>

# %%
# Test the function
print(get_actors_for_title("Taxi Driver"))
# Out:
# Robert De Niro, Jodie Foster, Albert Brooks, Harvey Keitel, Cybill Shepherd, Peter Boyle, Leonard Harris, Diahnne Abbott, Gino Ardito, Martin Scorsese, Murray Moston, Richard Higgs, Bill Minkin, Bob Maroff, Victor Argo, Joe Spinell, Robinson Frank Adu, Brenda Dickson, Norman Matlock, Harry Northup, Harlan Cary Poe, Steven Prince, Peter Savage, Nicholas Shields, Ralph S. Singleton, Annie Gagen, Carson Grant, Mary-Pat Green, Debbi Morgan, Don Stroud, Copper Cunningham, Garth Avery, Nat Grant, Billie Perkins, Catherine Scorsese, Charles Scorsese, Odunlade Adekola, Ijeoma Grace Agu

# %% [markdown]
# ## Task 8: Creating a Function to Categorize Movies by IMDb Score
#
# Let’s categorize movies and shows based on their IMDb scores to provide a quick evaluation of their popularity or quality. We’ll create a function that takes in a `title` and returns a rating category based on the movie or show’s IMDb score.
#
# ### Rating Categories
#
# - **Excellent**: IMDb score of 9.0 or higher
# - **Good**: IMDb score between 7.0 and 8.9
# - **Average**: IMDb score between 5.0 and 6.9
# - **Low**: IMDb score below 5.0
#
# ### Instructions
#
# 1. **Define the Function**:
#    - Create a function called `categorize_imdb_score` that accepts one parameter, `title`.
#
# 2. **Filter by Title**:
#    - Inside the function, filter the DataFrame to find the row where `title` matches the given title.
#
# 3. **Retrieve IMDb Score**:
#    - If the title exists, retrieve the `imdb_score` for that movie or show.
#    - If the title is not found, return `"Title not found"`.
#
# 4. **Categorize Score with `if-else`**:
#    - Use `if-elif-else` statements to evaluate the `imdb_score` and return one of the rating categories based on the ranges provided.
#
# 5. **Return the Category**:
#    - Return the appropriate category based on the score.
#
# This function allows you to quickly categorize movies or shows by their IMDb score, which could be helpful for creating rating tags or recommending top-rated content.

# %%
# Define the function
def categorize_imdb_score(title):
    # Filter for the row with the specified title
    selected_media = df[df['title'] == title]

    # Check if title exists
    if selected_media.empty: #pandas Boolean in documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.empty.html
        return "Title not found" #Didn't have to explicitly assign the boolean == True condition for this logic to work
        
    # Retrieve the IMDb score for the movie
    score = selected_media.loc[0,'imdb_score'] #Selecting one cell
        
        # Categorize score using if-else and return the ranking accordingly
    if (score >= 9.0): #if statements can be on the same level in the simplified logic without preceeding elifs
        return "Excellent"
    elif (7.0 <= score) & (score <= 8.9):
        return "Good"
    elif (5.0 <= score) & (score <= 6.9):
        return "Average"
    elif score < 5.0:
        return "Low"

#The v3 codeblock above builds a string, as required
#The v4 codeblock removed for loop logic accounting for remakes when Series.size >1 https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.shape.html
#Duplicates titles are handled by explictly picking the first result via basic one-cell .loc[] call for label-based indexing
###Can also be done with the .iloc[] integer-location-based indexing call
#Cut many intermediary variables to reduce to simplest input-output pipeline

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment, Iteration 1</b> <a class="tocSkip"></a>
#
# This function is meant to *return* a category string (e.g., "Good") or exactly "Title not found". Right now it prints messages and returns `None`, which makes it hard to reuse programmatically and doesn’t match the required return value. Consider returning the string result and letting the caller decide whether to print it.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment V2</b>
#
# The return is supposed to be a single string.
#
# This function contains far too much complexity for such a simple problem that you have been given. Yes there is more than one movie released with the same name, just get the score for one of them and return the string required.
# </div>

# %% [markdown]
# <div style="background-color: #d4edda; color: #155724; padding: 15px; border-radius: 4px; border: 1px solid #c3e6cb;">
#
# <b>Reviewer's comment v4</b>
#
# Well done!

# %%
# Test the function
print(categorize_imdb_score("Braxi Driver"))
print(categorize_imdb_score("Taxi Driver"))
# Out:
# Title not found
# Good

# %% [markdown]
# <span style="color:red">**I learned a lot in Task 8. What a neat problem to be dealing with.**</span>

# %% [markdown]
# <span style="color:red">**After Dot Review 1: I'm moderately disappointed in the directions coverage of handling trickiness in the datasets. I figured they were hidden component challenges to navigate, but the way Dot responded seems to indicate I was expected to ignore problems rooted in the .csv's butchered column data. I still made revisions that were clear to make and were a product of me initially overlooking parts of the task instructions.**</span>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment V2</b>
#
# Please explain the comment about the butchered column data.
# </div>

# %% [markdown]
# <span style="color:black">After Review 2: I've stripped excess from the project while fielding comments. I have saved previous copies of the projects I've submitted here, so none of what I wrote is lost. To speak on the dataset butchering - the initial .csv had artifacts in it that made handling the Tasks as-written difficult. I know enough to know that those exceptions/strangeness can be accounted for in some way so the programs I write gracefully handles them if they threaten my result, but clarification in advance on future projects as to whether or not certain exception cases need to be accounted for (like in Task 8 when a simpler construction of the solution initially does output 2 scores for 1 title) or not would be beneficial so as to clarify expectations for how much the student is expected to account for in the final solution. I reckon on the job I would be expected to cover all significant exceptions unless expressly told to ignore them, or unless accounting for exceptions is explicitly irrelevant (hypothetical failstates) to the scope of my assignment.</span>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment v3:</b> <a class="tocSkip"></a>
#
# Your solution is creative and technically thoughtful — I can see that you tried to make it more robust by handling duplicates and returning detailed formatted messages. That shows initiative. 👍
#
# However, for this task, the goal is to follow the specification exactly.
#
# The function must return **only one of these strings**:
# - "Excellent"
# - "Good"
# - "Average"
# - "Low"
#
# And if the title is not found, it must return exactly:
# - "Title not found"
#
# Right now, the function is a little **over-engineered** for what the task requires, and the output format does not match the expected result. In project-based learning (and in real production environments), matching the exact required output is critical.
#
# So, please **simplify** the function to:
# - Extract the score for the title
# - Apply the category logic
# - Return only the category string (no extra formatting or explanations)
#
# Once this is aligned with the task requirements, this section and the whole project will be complete.
# </div>

# %% [markdown]
# <div style="background-color: #d4edda; color: #155724; padding: 15px; border-radius: 4px; border: 1px solid #c3e6cb;">
#
# <b>Reviewer's comment v4</b>
#
# Well done!

# %% [markdown]
# <span style="color:green">**All Comments Resolved - 03MAR2026**</span>
